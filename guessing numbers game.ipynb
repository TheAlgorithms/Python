# %%
# numbers game

# %%
import random
name=input("Enter your name: ")
print(f"\nHello {name} welcome to guessing game")
chances=10
number=random.randint(0,100)
guessing=0

play="yes"
def playagain():
    global play
    play=input("Do you want to play this game again? (yes/no) :")
    if play =="yes":
        global chances,number,guessing
        chances=10
        number=random.randint(0,100)
        guessing=0
    else:
        print("Thank you for playing")
while play=='yes':    
    while chances>0:
        won=True
        if number is guessing:
            print(ch,end="")
        else:
            print('_',end="")
            won=False
                
        if won:
            print("\nyou won the game")
            print(f"\nyour score is {chances*10} ")
            playagain()
            break
        guess=int(input("\nGuess a two digit number : "))
        guessing+=guess
        if guess < number:
            chances-=1
            print("\nWrong Answer!")
            print(f"\nyou have {chances} chances left")
            print("\nnumber is greater than your number!")
            
            if chances==0:
                print("\nyou lose the game!")
                playagain()
                break
        elif guess>number:
            chances-=1
            print("\nWrong Answer!")
            print("\nnumber is less than your number!")
            print(f"\nyou have {chances} chances left")
            if chances==0:
                print("\nyou lose the game!")
                playagain()
                break
        else:
            print("\nyou won the game")
            print(f"\nyour score is {chances*10} ")
            playagain()
            break
# Out:
# Enter your name: Aslam
#
# Hello Aslam welcome to guessing game
# _
# Guess a two digit number : 70
#
# Wrong Answer!
#
# number is less than your number!
#
# you have 9 chances left
# _
# Guess a two digit number : 50
#
# Wrong Answer!
#
# number is less than your number!
#
# you have 8 chances left
# _
# Guess a two digit number : 30
#
# Wrong Answer!
#
# you have 7 chances left
#
# number is greater than your number!
# _
# Guess a two digit number : 40
#
# Wrong Answer!
#
# number is less than your number!
#
# you have 6 chances left
# _
# Guess a two digit number : 35
#
# Wrong Answer!
#
# you have 5 chances left
#
# number is greater than your number!
# _
# Guess a two digit number : 37
#
# Wrong Answer!
#
# you have 4 chances left
#
# number is greater than your number!
# _
# Guess a two digit number : 38
#
# you won the game
#
# your score is 40
# Do you want to play this game again? (yes/no) :no
# Thank you for playing

# %%
import random
try:
    name=input("Enter your name: ")
    print(f"\nHello {name} welcome to guessing game")
    chances=10
    number=random.randint(0,100)
    guessing=0

    play="yes"
    def playagain():
        global play
        play=input("Do you want to play this game again? (yes/no) :")
        if play =="yes":
            global chances,number,guessing
            chances=10
            number=random.randint(0,100)
            guessing=0
        else:
            print("Thank you for playing")
    while play=='yes':    
        while chances>0:
            won=True
            if number is guessing:
                print(ch,end="")
            else:
                print('_',end="")
                won=False

            if won:
                print("\nyou won the game")
                print(f"\nyour score is {chances*10} ")
                playagain()
                break
            guess=int(input("\nGuess a two digit number : "))
            guessing+=guess
            if guess < number:
                chances-=1
                print("\nWrong Answer!")
                print(f"\nyou have {chances} chances left")
                print("\nnumber is greater than your number!")

                if chances==0:
                    print("\nyou lose the game!")
                    playagain()
                    break
            elif guess>number:
                chances-=1
                print("\nWrong Answer!")
                print("\nnumber is less than your number!")
                print(f"\nyou have {chances} chances left")
                if chances==0:
                    print("\nyou lose the game!")
                    playagain()
                    break
            else:
                print("\nyou won the game")
                print(f"\nyour score is {chances*10} ")
                playagain()
                break
except Exception:
    print('you enter a string')
finally:
    print(f"Thanks for playing {name}!!")
    print("Don't repeat this mistake agian!!")
# Out:
# Enter your name: Aslam
#
# Hello Aslam welcome to guessing game
# _
# Guess a two digit number : dk
# you enter a string
# Thanks for playingAslam!!
# Don't repeat this agian!!

# %%
pip install emoji --upgrade
# Out:
# Collecting emoji
#   Downloading emoji-2.1.0.tar.gz (216 kB)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=d1f9719e9a0d7c76114a87fee4562abe84a1a9c53ea3339500b184cc7dbab619
#   Stored in directory: c:\users\srit\appdata\local\pip\cache\wheels\b0\4a\c8\9c580a0ea94dea641b8023456a1b178a7e4509d992224ed4aa
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji
print(emoji.emojize('Hi there! :revolving_hearts:'))
# Out:
# Hi there! 💞
