# %%
#Question 1

import pandas as pd
df=pd.read_csv('weather.csv')
print("--------------------Number of cells with missing data------------------")
print(df.isnull().sum())


print("--------------------DataFrame With Missing Values Removed------------------")
df2=df.dropna()  #removing rows with missing values
print(df2)


print("-----------DataFrame With Missing Replaced By Mean Of Columns--------------")
df3=pd.read_csv('weather.csv')
for i in df3.axes[1] : 
    try:
        df3[i]=df3[i].fillna(df3[i].mean())
    except:                                  #to handle the exception if mean cannot be found like in case of date and string
                                             #so value from previous row will be filled
        df3[i]=df3[i].fillna(method='ffill') 
print(df3)


print("--------------------------Individual DataTypes-----------------------------")
print(df.dtypes)


print("----------------Temperature Column To Pandas Series------------------------")
s=pd.Series(df3['MinTemp']).rename('Temperature')  #renamed MinTemp to Temperature
print(s)
# Out:
# --------------------Number of cells with missing data------------------
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64
# --------------------DataFrame With Missing Values Removed------------------
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# ...
