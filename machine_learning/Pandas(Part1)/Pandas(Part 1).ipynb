# %%
#Question 1

import pandas as pd

df=pd.read_csv('frienddata.csv')  #i have saved my data in frienddata.csv
print(df)


#second method without reading from file

df2=pd.DataFrame({'Name':['Ankush','Aman','Ankit'],
                    'Age':[20,23,21],
                    'Mail-Id':['ankushgoyal310@gmail.com','aman1188.cse16@chitkara.edu.in','ankit1114.cse16@chitkara.edu.in'],
                    'Phone Number':[9417820611,9878744674,8749446344]})

print('\n',df2)
# Out:
#      Name  Age                          Mail-Id  Phone Number
# 0  Ankush   20         ankushgoyal310@gmail.com    9417820611
# 1    Aman   23   aman1188.cse16@chitkara.edu.in    9878744674
# 2   Ankit   21  ankit1114.cse16@chitkara.edu.in    8749446344
#
#       Name  Age                          Mail-Id  Phone Number
# 0  Ankush   20         ankushgoyal310@gmail.com    9417820611
# 1    Aman   23   aman1188.cse16@chitkara.edu.in    9878744674
# 2   Ankit   21  ankit1114.cse16@chitkara.edu.in    8749446344

# %%
#Question 2
df = pd.read_csv('data.csv')
print("--------------------------First 5  Rows--------------------------------")
print(df.head(5))  #or by slicing df[:5]
print("--------------------------First 10 Rows--------------------------------")
print(df.head(10))
print("-----------------Basic Statistics On Whole DataSet---------------------")
print(df.describe())
print("--------------------------Last  5  Rows--------------------------------")
print(df.head(5))
print("--------------------------Second Column--------------------------------")
print(df['Location'])
print("-----------------Basic Statistics On Second Column---------------------")
print(df['Location'].describe())
# Out:
# --------------------------First 5  Rows--------------------------------
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
# ...
